# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOGNA-537/NASSCOM_WEEK1/blob/main/python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")
if True:
    print("This is indented correctly.")
else:
    print("This won't run.")
# Out:
# Hello, Python!
# This is indented correctly.

# %%
name='alice'
age=25
height=5.6
print("name:",name)
print("age:",age)
print("height:",height)
name=123
print("newnmae:",name)
# Out:
# name: alice
# age: 25
# height: 5.6
# newnmae: 123

# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
b=3.14
print(type(b))
# Out:
# <class 'float'>

# %%
c='python'
print(type(c))
d=True
print(type(d))
e=[1,2,3,'four']
print(type(e),e)
f={'name':'alice','age':25}
print(type(f),f)
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'alice', 'age': 25}

# %%
print("Welcome to python I/O!")
# Out:
# Welcome to python I/O!

# %%
user_name=input("enter your name:")
print("Hello ",user_name)
# Out:
# enter your name:manogna
# Hello  manogna

# %%
user_age=int(input("enter your age:"))
print("you will be ",user_age+1,"next year")
# Out:
# enter your age:22
# you will be  23 next year
